# %% [markdown]
# # ABF Q1 — Persistence & Reversal Analysis
#
# **ABF Question 1 (Part 2):** Test whether shocks create measurable autocorrelation regimes.
#
# **Mechanism hypothesis:** After high-vol shocks, vol-targeting strategies create:
# 1. Short-term momentum persistence (5-day horizon)
# 2. Medium-term reversal probability (1-month horizon)
#
# **Identification:** Local projection — r_{t+h} = α + β₁·Shock_t + β₂·(Shock_t × VolControlProxy_t) + γ·X_t + ε_{t+h}
#
# ---
#
# **Status:** Placeholder — Phase A2
#
# **See:** `harbor.abf.q1` and `docs/abf-prd.md` for full spec.

# %% [markdown]
# ## Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# HARBOR imports (Phase A2)
# from harbor.data import load_sp500
# from harbor.risk.regime_detection import detect_vol_shocks
# from harbor.backtest.metrics import cumulative_abnormal_return

print('ABF Q1 Persistence & Reversal — Phase A2')

# %% [markdown]
# ## 1. Event Study — Cumulative Abnormal Returns

# %%
# For each shock date t, compute forward CARs at h = {1, 5, 21} days
# Compare: shock regime vs non-shock regime
#
# car_results = cumulative_abnormal_return(returns, event_dates=shock_dates, horizon=21)
#
# Expected pattern (if hypothesis holds):
#   h=5:  car_shock > car_baseline  (persistence)
#   h=21: car_shock < car_baseline  (reversal)
raise NotImplementedError('Implement cumulative_abnormal_return — Phase A2')

# %% [markdown]
# ## 2. Local Projection Regressions

# %%
# Pre-specified regression (from PRD Table 1):
#   r_{t+h} = α + β₁·Shock_t + β₂·(Shock_t × VolControlProxy_t) + γ·X_t + ε_{t+h}
#
# for h in [1, 5, 21]:
#     X = pd.DataFrame({'shock': shocks, 'interaction': shocks * vol_proxy, **controls})
#     X = sm.add_constant(X)
#     model = sm.OLS(returns.shift(-h), X).fit(cov_type='HAC', cov_kwds={'maxlags': h})
#     print(f'h={h}: β₁={model.params["shock"]:.4f}, β₂={model.params["interaction"]:.4f}, p={model.pvalues["interaction"]:.4f}')
#
# SUCCESS CRITERIA (from PRD):
#   β₂ significant (p<0.05), opposite signs at h=5 vs h=21
raise NotImplementedError('Implement local projection regressions — Phase A2')

# %% [markdown]
# ## 3. Robustness Checks (Pre-Specified)

# %%
# MANDATORY robustness checks (do not skip):
#   1. Alternative shock definitions (Alt 1, 2, 3 from shock_definition notebook)
#   2. Sub-sample splits: pre-2020 vs post-2020
#   3. Sub-sample splits: high-liquidity vs low-liquidity periods
#   4. Newey-West standard errors at varying lag lengths
#   5. Bootstrap inference (block bootstrap, 1000 replications)
#
# Document ALL results — null results are also informative.
raise NotImplementedError('Implement after primary results are stable — Phase A2')

# %% [markdown]
# ## 4. Figures for Paper

# %%
# Target figures (working-paper quality):
#   Fig 1: Shock event timeline (realized vol with shock dates marked)
#   Fig 2: Average CAR paths (shock vs non-shock, with confidence bands)
#   Fig 3: Local projection coefficients across horizons h=1..30
#   Fig 4: Interaction term β₂ by vol-control proxy tercile
#
# Store to notebooks/outputs/ (gitignored)
raise NotImplementedError('Implement figures after results are stable — Phase A2/A3')
