# %% [markdown]
# # ABF Q1 — Shock Definition
#
# **ABF Question 1 (Part 1):** Define and validate volatility shocks used in the event-study design.
#
# **Goal:** Pre-specify the shock definition so that subsequent persistence/reversal analysis is not data-mined.
#
# **Pre-specified test (from PRD):**
# - Shock = top 5% of 1-day realized volatility changes OR VIX jump > threshold
# - Document alternative definitions for robustness checks
#
# ---
#
# **Status:** Placeholder — Phase A2
#
# **See:** `hangar.abf.q1` and `docs/abf-prd.md` for full spec.

# %% [markdown]
# ## Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# HANGAR imports (Phase A2 — implement these)
# from hangar.data import load_sp500
# from hangar.risk.regime_detection import detect_vol_shocks

print('ABF Q1 Shock Definition notebook — Phase A2')
print('Implement hangar.data and hangar.risk.regime_detection first.')

# %% [markdown]
# ## 1. Load Universe and Returns

# %%
# Load SP500 daily returns (survivorship-bias-free)
# Universe: 2010-2026, daily frequency
# Source: CRSP/WRDS (PERMNO identifiers)

# returns = load_sp500(start='2010-01-01', end='2026-01-01')
# print(f'Universe: {returns.shape[1]} assets, {returns.shape[0]} days')
raise NotImplementedError('Implement hangar.data.load_sp500 — Phase H1')

# %% [markdown]
# ## 2. Volatility Shock Definition (Pre-Specified)

# %%
# PRIMARY DEFINITION (pre-specified, do not change after first run)
#   Shock = realized_vol_change > 95th percentile of full-sample distribution
#
# ALTERNATIVE DEFINITIONS (for robustness checks only):
#   Alt 1: VIX absolute level > 30
#   Alt 2: Top 5% of intraday range (high-low / close)
#   Alt 3: Top 5% of 5-day realized vol (not 1-day)

# shocks = detect_vol_shocks(returns, threshold_pct=0.95)
# print(f'Shock dates identified: {shocks.sum()}')
raise NotImplementedError('Implement hangar.risk.regime_detection — Phase A2')

# %% [markdown]
# ## 3. Descriptive Statistics & Validation

# %%
# Validate shock dates:
#   - Distribution of shocks across time (not clustered unexpectedly)
#   - Average realized vol on shock vs non-shock days
#   - Shock coincidence with known macro events (COVID, GFC, 2022 vol spike)
#
# fig, axes = plt.subplots(2, 1, figsize=(12, 8))
# axes[0].plot(realized_vol, label='Realized Vol')
# axes[0].axhline(shock_threshold, color='red', linestyle='--', label='Shock Threshold')
# ...
raise NotImplementedError('Implement after load_sp500 and detect_vol_shocks')

# %% [markdown]
# ## 4. Vol-Control Proxy Construction

# %%
# Construct vol-control pressure proxy
# Options (pick one primary, others for robustness):
#   A. Risk-parity rebalancing proxy (inverse vol weight changes)
#   B. ETF flow reversals (SPY/IVV/VOO outflows around shocks)
#   C. GARCH(1,1) forecast-based exposure scaling
#
# This proxy is the KEY identification instrument for ABF Q1:
# We test whether persistence is strongest when this proxy is ELEVATED,
# not merely when volatility is high — this separates manufactured
# autocorrelation from natural volatility clustering.
raise NotImplementedError('Implement vol-control proxy — Phase A2')
